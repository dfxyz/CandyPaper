# %% [markdown]
# # Candy Paper Preview

# %%
import importlib

if 'CandyPaper' in dir():
    importlib.reload(CandyPaper)
else:
    CandyPaper = importlib.import_module('CandyPaper')

# %% [markdown]
# ## Light Scheme

# %% [markdown]
# ### Basic Colors

# %%
CandyPaper.previewLightBasicColors()
# Out:
# <div style="background-color:#F4FFE8;"><p style="color:#406080;">defaultFg: hex=#406080; hsv=(210, 50, 50), rgb=(64, 96, 128)</p><p style="color:#406080;">defaultBg: hex=#F4FFE8; hsv=(90, 10, 100), rgb=(244, 255, 232)</p><p style="color:#6090C0;">altFg1: hex=#6090C0; hsv=(210, 50, 75), rgb=(96, 144, 192)</p><p style="color:#9CA89C;">altFg2: hex=#9CA89C; hsv=(120, 5, 65), rgb=(156, 168, 156)</p><p style="color:#CC0000;">red: hex=#CC0000; hsv=(0, 100, 80), rgb=(204, 0, 0)</p><p style="color:#CC6800;">orange: hex=#CC6800; hsv=(30, 100, 80), rgb=(204, 104, 0)</p><p style="color:#806800;">yellow: hex=#806800; hsv=(50, 100, 50), rgb=(128, 104, 0)</p><p style="color:#5C8000;">oliveGreen: hex=#5C8000; hsv=(75, 100, 50), rgb=(92, 128, 0)</p><p style="color:#008000;">green: hex=#008000; hsv=(120, 100, 50), rgb=(0, 128, 0)</p><p style="color:#008C8C;">cyan: hex=#008C8C; hsv=(180, 100, 55), rgb=(0, 140, 140)</p><p style="color:#0000C0;">blue1: hex=#0000C0; hsv=(240, 100, 75), rgb=(0, 0, 192)</p>
# ...

# %% [markdown]
# ### Vim Groups

# %%
CandyPaper.previewLightVimGroups()
# Out:
# <div style="color:#406080;background-color:#F4FFE8;"><p style="color:#406080;background-color:#F4FFE8;">[Normal]<br>defaultFg: hex=#406080; hsv=(210, 50, 50), rgb=(64, 96, 128)<br>defaultBg: hex=#F4FFE8; hsv=(90, 10, 100), rgb=(244, 255, 232)</p><p style="color:#406080;">[Identifier]<br>defaultFg: hex=#406080; hsv=(210, 50, 50), rgb=(64, 96, 128)<br>bg: None</p><p style="color:#406080;">[Operator]<br>defaultFg: hex=#406080; hsv=(210, 50, 50), rgb=(64, 96, 128)<br>bg: None</p><p style="color:#406080;">[Delimiter]<br>defaultFg: hex=#406080; hsv=(210, 50, 50), rgb=(64, 96, 128)<br>bg: None</p><p style="color:#CC6800;">[Number]<br>orange: hex=#CC6800; hsv=(30, 100, 80), rgb=(204, 104, 0)<br>bg: None</p><p style="color:#806800;">[PreProc]<br>yellow: hex=#806800; hsv=(50, 100, 50), rgb=(128, 104, 0)<br>bg: None</p><p style="color:#806800;">[SpecialComment]<br>yellow: hex=#806800; hsv=(50, 100, 50), rgb=(128, 104, 0)<br>bg: None</p><p style="color:#5C8000;">[Comment]<br>oliveGreen: hex=#5C8
# ...

# %% [markdown]
# ## Dark Scheme

# %% [markdown]
# ### Basic Colors

# %%
CandyPaper.previewDarkBasicColors()
# Out:
# <div style="background-color:#202820;"><p style="color:#94A8A8;">defaultFg: hex=#94A8A8; hsv=(180, 10, 65), rgb=(148, 168, 168)</p><p style="color:#94A8A8;">defaultBg: hex=#202820; hsv=(120, 20, 15), rgb=(32, 40, 32)</p><p style="color:#688080;">altFg1: hex=#688080; hsv=(180, 20, 50), rgb=(104, 128, 128)</p><p style="color:#606860;">altFg2: hex=#606860; hsv=(120, 5, 40), rgb=(96, 104, 96)</p><p style="color:#E85C5C;">red: hex=#E85C5C; hsv=(0, 60, 90), rgb=(232, 92, 92)</p><p style="color:#CCA054;">orange: hex=#CCA054; hsv=(40, 60, 80), rgb=(204, 160, 84)</p><p style="color:#A8A844;">yellow: hex=#A8A844; hsv=(60, 60, 65), rgb=(168, 168, 68)</p><p style="color:#8CA844;">oliveGreen: hex=#8CA844; hsv=(75, 60, 65), rgb=(140, 168, 68)</p><p style="color:#44A844;">green: hex=#44A844; hsv=(120, 60, 65), rgb=(68, 168, 68)</p><p style="color:#20A8A8;">cyan: hex=#20A8A8; hsv=(180, 80, 65), rgb=(32, 168, 168)</p><p style="color:#3498FF;">blue1: hex=#3498FF; hsv=(210, 80, 100), rgb=(52, 152, 255)
# ...

# %% [markdown]
# ### Vim Groups

# %%
CandyPaper.previewDarkVimGroups()
# Out:
# <div style="color:#94A8A8;background-color:#202820;"><p style="color:#94A8A8;background-color:#202820;">[Normal]<br>defaultFg: hex=#94A8A8; hsv=(180, 10, 65), rgb=(148, 168, 168)<br>defaultBg: hex=#202820; hsv=(120, 20, 15), rgb=(32, 40, 32)</p><p style="color:#94A8A8;">[Identifier]<br>defaultFg: hex=#94A8A8; hsv=(180, 10, 65), rgb=(148, 168, 168)<br>bg: None</p><p style="color:#94A8A8;">[Operator]<br>defaultFg: hex=#94A8A8; hsv=(180, 10, 65), rgb=(148, 168, 168)<br>bg: None</p><p style="color:#94A8A8;">[Delimiter]<br>defaultFg: hex=#94A8A8; hsv=(180, 10, 65), rgb=(148, 168, 168)<br>bg: None</p><p style="color:#CCA054;">[Number]<br>orange: hex=#CCA054; hsv=(40, 60, 80), rgb=(204, 160, 84)<br>bg: None</p><p style="color:#A8A844;">[PreProc]<br>yellow: hex=#A8A844; hsv=(60, 60, 65), rgb=(168, 168, 68)<br>bg: None</p><p style="color:#A8A844;">[SpecialComment]<br>yellow: hex=#A8A844; hsv=(60, 60, 65), rgb=(168, 168, 68)<br>bg: None</p><p style="color:#8CA844;">[Comment]<br>oliveGreen: hex
# ...
